# %%
def replace_word():
    
    str = input("masukkan kalimat: ")
    word_to_replace = input("masukkan kata yang ingin diganti: ")
    word_replacement = input("masukkan kata untuk mengganti: ")
    print(str.replace(word_to_replace, word_replacement))
    

replace_word()

# %%
#define the functions needed, add, sub, mul, div
#print option to the user
#ask for values
#call the functions
#while loop to continue the program until the users want to exit

def add(a, b):
    answer = a + b
    print ( str(a) + " + " + str(b) + " = " + str(answer) + "\n")
    
def sub(a, b):
    answer = a - b
    print ( str(a) + " - " + str(b) + " = " + str(answer) + "\n")

def mul(a, b):
    answer = a * b
    print ( str(a) + " x " + str(b) + " = " + str(answer) + "\n")

def div(a, b):
    answer = a / b
    print ( str(a) + " : " + str(b) + " = " + str(answer) + "\n")
    
while True:
    print("A. Addition ")
    print("B. Subtraction ")
    print("C. Multiplication ")
    print("D. Division ")
    print("E. Exit")

    choice =  input("masukkan pilihan kamu ? ")

    if choice == "a" or choice == "A":
        print("Addition")
        a = int(input("input angka pertama :"))
        b = int(input("input angka kedua: "))
        add(a, b)
    elif choice == "b" or choice == "B":
        print("Subtraction")
        a = int(input("input angka pertama :"))
        b = int(input("input angka kedua: "))
        sub(a, b)
    elif choice == "c" or choice == "C":
        print("Multiplication")
        a = int(input("input angka pertama :"))
        b = int(input("input angka kedua: "))
        mul(a, b)
    elif choice == "d" or choice == "D":
        print("Division")
        a = int(input("input angka pertama :"))
        b = int(input("input angka kedua: "))
        div(a, b)
    elif choice == "e" or choice == "E":
        print("Exit")
        exit()

# %%
#collect email from user
#split the email using the @, the second part is gonna be saved as domain
#split using .

def main():
    print("welcome to the email slicer")
    print("")
    
    email_input = input("masukkan email: ")
    (username, domain) = email_input.split("@")
    (domain, extension) = domain.split(".")
    
    print("Username: ",username)
    print("Domain: ", domain)
    print("Extension:", extension)

while True:
    main()

# %%
#function that takes the list dan target parameter
#multiple variables: middle, start, steps
#recursion or while loop
#increase the steps each time a split is done
#conditions to track target position

def binary_search(list, element):
    middle = 0
    start = 0
    end = len(list)
    steps = 0
    
    while(start<=end):
        print("steps ",steps, " : ", str(list[start:end+1]))
        
        steps = steps + 1
        middle = (start + end) // 2
        
        if element == list[middle]:
            return middle
        if element < list[middle]:
            end = middle -1
        else:
            start = middle + 1
    return -1

# %%
# a dictionary that stores questions and answer
# have a variable that tracks the score of the players
# loop through the dictionary using the key values pairs
# display each question to the user and allow them to answer
# tell them if they are right or wrong 
# show the final result when quiz is completed

quiz = {
    "question1":{
        "question": "Kamu tahu kenapa menara pisa miring ?",
        "answer": "Karena ketarik sama senyummu "
    },
    "question2":{
        "question": "Salep apa yang bikin luka tambah parah ?",
        "answer": "Salepas kau pergi, ku masih berharap kau kembali "
    },
    "question3":{
        "question": "Kamu tau gak apa bedanya kamu sama mantanku ?",
        "answer": "Kalau mantan adalah masa laluku, kalau kamu adalah masa depanku. "
    },
    "question4":{
        "question": "Apa bedanya kamu sama kipas ?",
        "answer": "Kipas bisa bikin angin, kalo kamu bisa bikin angen"
    },
    "question5":{
        "question": "Apa bedanya jam dinding sama kamu ?",
        "answer": "Kalau jam dinding dipajang di dinding, kalau kamu dipajang di hati aku."
    },
    "question6":{
        "question": "Kucing apa yang super romantis ?",
        "answer": "Kucingta padamu."
    }
}

score = 0

for key, value in quiz.items():
    print(value['question'])
    answer = input("Jawabanmu :")
    
    if answer.lower() == value['answer'].lower():
        print("betul !!")
        score = score + 1
        print("Skor kamu sekarang adalah: ", str(score))
        print("")
        print("")
    else:
        print("salah !!")
        print("Jawaban yang benar adalah : " + value['answer'])
        print("Skor kamu sekarang adalah: ", str(score))
        print("")
        print("")

print("kamu mendapat skor :" + str(score) + " out of 6 questions correctly")
print("Your percentage is " + str(int(score/6 * 100)) + "%")
# Out:
# Kamu tahu kenapa menara pisa miring ?
# Jawabanmu :gatau
# salah !!
# Jawaban yang benar adalah : Karena ketarik sama senyummu
# Skor kamu sekarang adalah:  0
#
#
# Salep apa yang bikin luka tambah parah ?
# Jawabanmu :Salepas kau pergi, ku masih berharap kau kembali
# salah !!
# Jawaban yang benar adalah : Salepas kau pergi, ku masih berharap kau kembali
# Skor kamu sekarang adalah:  0
#
#
# Kamu tau gak apa bedanya kamu sama mantanku ?
# Jawabanmu :Kalau mantan adalah masa laluku, kalau kamu adalah masa depanku.
# betul !!
# Skor kamu sekarang adalah:  1
#
#
# Apa bedanya kamu sama kipas ?
# Jawabanmu :gatau
# salah !!
# Jawaban yang benar adalah : Kipas bisa bikin angin, kalo kamu bisa bikin angen
# Skor kamu sekarang adalah:  1
#
#
# Apa bedanya jam dinding sama kamu ?
# Jawabanmu :gatau
# salah !!
# Jawaban yang benar adalah : Kalau jam dinding dipajang di dinding, kalau kamu dipajang di hati aku.
# Skor kamu sekarang adalah:  1
#
#
# Kucing apa yang super romantis ?
# ...

# %%
import random

def roll_dice():

    dice_drawing = {
        1: (
            "-----",
            "|   |",
            "| o |",
            "|   |",
            "-----",
        ),
        2: (
            "-----",
            "|o  |",
            "|   |",
            "|  o|",
            "-----",
        ),
        3: (
            "-----",
            "|o  |",
            "| o |",
            "|  o|",
            "-----",
        ),
        4: (
            "-----",
            "|o o|",
            "|   |",
            "|o o|",
            "-----",
        ),
        5: (
            "-----",
            "|o o|",
            "| o |",
            "|o o|",
            "-----",
        ),
        6: (
            "-----",
            "|o o|",
            "|o o|",
            "|o o|",
            "-----",
        ),

    }
    roll = input("Roll the dice? (Yes/No) : ")
    while roll.lower() == "Yes". lower():
        dice1 = random.randint(1, 6)
        dice2 = random.randint(1, 6)

        print("dice rolled: {} and {}". format(dice1, dice2))
        print("\n".join(dice_drawing[dice1]))
        print("\n".join(dice_drawing[dice2]))
        
        roll = input("Roll again? (Yes/no): ")
roll_dice()
# Out:
# Roll the dice? (Yes/No) : yes
# dice rolled: 4 and 3
# -----
# |o o|
# |   |
# |o o|
# -----
# -----
# |o  |
# | o |
# |  o|
# -----
